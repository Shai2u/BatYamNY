# %% [markdown]
# ## <h1>Simulation Simple Iteration "Cimulation" Israel Bat Yam Version March 6 (update march 28)</h1>
# this is a proof of concept that the simulation works and that it's solid.
# this simultation doesn't hold all the correct data, as the data is fautlty and rework is needed to it
# what this simulation has is 5 iterations
# the first 3 iterations are Tama 38/1
# the 4th iteration is Tama 38/2
# and the 5th iteration is an example of a Taba Planning

# %% [markdown]
# <h1>step 1: Loading the files</h1>

# %%
from ssi_GEOPACKAGE_march_28 import SSI

# %%
ssi = SSI()
display(ssi.simulation_folder)
# Out:
# Text(value='cim_0326_1234', description='Folder:')

# %% [markdown]
# ## Reference to the dictionary File
# ### Initiate GIS files load old buildings, background buildings and new updated buildings
# ### Dictionary File is important to keep a reference of the main files for the simulation

# %%
display(ssi.agents_name)
# Out:
# Text(value='agents.xlsx', description='Agent File')

# %%
ssi.init_gis()
ssi.init_db()

# %% [markdown]
# <h2>Files have been loaded</h2>
# <h1>step 2:Displyaing the the original buildings Using Folium and displaying statistics to them</h1>

# %%
display (ssi.before_map)
# Out:
# Checkbox(value=False, description='Display Before Map?', indent=False)

# %%
if (ssi.before_map.value):
    fmap = ssi.prepare_old_bldgs_map()
    display(fmap)
    fmap2 = ssi.prepare_agents_statistics_map_0()
    display(fmap2)

# %%
if (ssi.before_map.value):
    fmap2.save('map_march_28_itr_0.html')
    fmap.save('map_march_28_itr_0_bld_info.html')

# %% [markdown]
# <h1>step 3: setting up first iteration of simulation</h1>
# <h2>Adding Threshold ability to stay for each agent and initalStatus<h2/>
#     <h2>Here I am initating datsets for referncing the differnet excel sheets in each iteration</h2>
#     <h2>lets give a name to this simulation and control the iteration</h2>

# %%
display(ssi.simulation_name)
# Out:
# Text(value='agents_cim_0330_1957', description='Simulation Name')

# %% [markdown]
# <h2>controlling iteration</h2>

# %%
ssi.set_up_first_iteration()

# %%
display(ssi.AutoNameSimulation)
# Out:
# Checkbox(value=False, description='Auto Name Simulation?', indent=False)

# %%
if ssi.AutoNameSimulation.value:
    pass
else:
    display(ssi.simulation_name)
# Out:
# Text(value='agents_cim_0330_1957', description='Simulation Name')

# %%
display(ssi.itr_slider)
# Out:
# IntSlider(value=0, max=24)

# %% [markdown]
# <h1 >TODO 1. !!! Need to create a flat file with a description of all the projects for each building</h1>

# %% [markdown]
# <h1>step 4: starting iteration</h1>

# %%
#ssi.iterate()

# %%
ssi.iterateAll()
# Out:
# Iteration Number: 0
# Address or complex: 215_22
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 1
# Address or complex: 216_10
# Type of project תמ״א 38/1
# operation 1 or 2
# /Users/shai/Google Drive/BatYam NY DRIVE/Simulations/March 14 GitHUB/BatYamNY/Jupyter/ssi_GEOPACKAGE_march_28.py:319: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.after_buildings['add_door_2'] = self.after_buildings['bldAdd']+"_"+self.after_buildings['appUnits'].astype(str)
# /Users/shai/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Iteration Number: 2
# Address or complex: 216_4
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 3
# Address or complex: 216_7
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 4
# Address or complex: 215_15
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 5
# Address or complex: 209_6
# Type of project תמ״א 38/2
# operation 1 or 2
# Iteration Number: 6
# Address or complex: 209_8
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 7
# Address or complex: 208_12
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 8
# Address or complex: 210_56
# Type of project תמ״א 38/2
# operation 1 or 2
# Iteration Number: 9
# Address or complex: 210_11
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 10
# Address or complex: 216_3
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 11
# Address or complex: 215_18
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 12
# Address or complex: 215_24
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 13
# Address or complex: 220_4
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 14
# Address or complex: complex_215_2
# Type of project תב״ע פינוי בינוי
# operation 3
# Iteration Number: 15
# Address or complex: complex_16
# Type of project תב״ע פינוי בינוי
# operation 3
# Iteration Number: 16
# Address or complex: 212_53
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 17
# Address or complex: complex_17
# Type of project תב״ע פינוי בינוי
# operation 3
# Iteration Number: 18
# Address or complex: ﻿215_14n
# Type of project תב״ע פינוי בינוי
# operation 3
# Iteration Number: 19
# Address or complex: 209_33c
# Type of project תמ״א 38/2
# operation 1 or 2
# Iteration Number: 20
# Address or complex: 215_6
# Type of project תמ״א 38/2
# operation 1 or 2
# Iteration Number: 21
# Address or complex: 209_29
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 22
# Address or complex: 209_4
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 23
# Address or complex: 217_5
# Type of project תמ״א 38/1
# operation 1 or 2
# Iteration Number: 24
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 24
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-716f86be16ed> in <module>
# ----> 1 ssi.iterateAll()
#
# ~/Google Drive/BatYam NY DRIVE/Simulations/March 14 GitHUB/BatYamNY/Jupyter/ssi_GEOPACKAGE_march_28.py in iterateAll(self)
#     296         for j in range(l_op+1):
#     297             self.itr_slider.value = j
# --> 298             self.iterate()
#     299     #helper function operation 12
#     300     def operation_12(self):
#
# ~/Google Drive/BatYam NY DRIVE/Simulations/March 14 GitHUB/BatYamNY/Jupyter/ssi_GEOPACKAGE_march_28.py in iterate(self)
#     243         print("Iteration Number: " + str(i))
#     244         # reference of the next row
# --> 245         self.next_row = self.script_file.loc[i]
#     246         #step 4.1: grabing the next row in script file, and getting a refenrence of the excel file
#     247         self.before_buildings = self.bna[(self.bna['iteration']==i) & (self.bna['renewd']=='before')] #before buildings
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 24

# %%
#need to test out case 3
# need to save in excel
# need to do smart iteration statistics

# %%
ssi.agents_all_iterations.to_excel('agents_march_30_1.xlsx')

# %% [markdown]
# <h1>step 4.1: grabing the next row in script file, and getting a refenrence of the excel file</h1>
# <h2>Units ifnromation of the updated building:</h2>
# <h1>step 2.2: duplicating the agent file</h1>
# <h1>step 2.3: merging the building details with the agent details</h1>
# <h1>step 4.2: Have a refernece of the active rows</h1>
# <h1>step 4.3 set the simplest descion tree possible</h1>
#
# ## 1. if the agent is renting he will leave in all cases
# ## 2. if the agent is not renting, he will leave if he cannot pay monthly bills and maintances
# <h1>step 4.5: getting refernece of avilable appartments and generating new agents (or grabing them from other sources)</h1>
# <h1>step 5. Saving the excel to a file and appending it into a a new dataset</h2>

# %%
ssi.agent_i['ones'] = 1
pivot_status = ssi.agent_i.pivot(index='AgentID',columns='Agent_status',values='ones')

del pivot_status.index.name


agent_i_export = ssi.agent_i.copy()
agent_i_export[['laeving','new comers','staying']] = pivot_status
#remeber to remove this pivot before next iteration
#agent_i_export['iteration']=str(i)

# %%
agent_i_export
# Out:
#      index  Age  AgeGroup AgeGroupDesc  AgentAppUnit AgentBldAdd  AgentID  \
# 0        0   33         0        Young             0      215_22        0
# 1        1   74         1          Old             1      215_22        1
# 2        2  106         1          Old             2      215_22        2
# 3        3   44         0        Young             3      215_22        3
# 4        4   35         0        Young             4      215_22        4
# 5        5  107         1          Old             5      215_22        5
# 6        6   42         0        Young             6      215_22        6
# 7        7   51         0        Young             7      215_22        7
# 8        8   25         0        Young             8      215_22        8
# 9        9   82         1          Old             9      215_22        9
# 10      10   51         0        Young            10      215_22       10
# 11      11   56         0        Young            11      215_22       11
# 12      12  101         1          Old            12      215_22       12
# 13      13   82         1          Old            13      215_22       13
# 14      14   79         1          Old            14      215_22       14
# 15      15   98         1          Old            15      215_22       15
# 16      16   93         1          Old            16      215_22       16
# 17      17   59         0        Young            17      215_22       17
# 18      18   85         1          Old             0      216_10       18
# 19      19  102         1          Old             1      216_10       19
# 20      20   54         0        Young             2      216_10       20
# 21      21   73         1          Old             3      216_10       21
# 22      22   64         0        Young             4      216_10       22
# 23      23   83         1          Old             5      216_10       23
# 24      24   95         1          Old             6      216_10       24
# 25      25   98         1          Old             7      216_10       25
# 26      26   95         1          Old             8      216_10       26
# 27      27   55         0        Young             9      216_10       27
# 28      28  107         1          Old            10      216_10       28
# 29      29   44         0        Young            11      216_10       29
# ..     ...  ...       ...          ...           ...         ...      ...
# 559    559   59         0        Young             8       217_5      559
# 560    560  103         1          Old             9       217_5      560
# 561    561   67         1          Old            10       217_5      561
# 562    562  107         1          Old            11       217_5      562
# 563    563   98         1          Old            12       217_5      563
# 564    564   88         1          Old            13       217_5      564
# 565    565   41         0        Young            14       217_5      565
# 566    566   33         0        Young            15       217_5      566
# 567    567  103         1          Old            16       217_5      567
# 568      0   25         0        Young             6      215_22      568
# 569      1   63         0        Young            10      215_22      569
# 570      2   68         1          Old            11      215_22      570
# 571      3   45         0        Young            15      215_22      571
# 572      4   59         0        Young            16      215_22      572
# 573      5   46         0        Young            17      215_22      573
# 574      6   36         0        Young            18      215_22      574
# 575      7   30         0        Young            19      215_22      575
# 576      8   32         0        Young            20      215_22      576
# 577      9   60         0        Young            21      215_22      577
# 578     10   50         0        Young            22      215_22      578
# 579     11   96         1          Old            23      215_22      579
# 580     12   52         0        Young            24      215_22      580
# 581     13   32         0        Young            25      215_22      581
# 582     14   26         0        Young            26      215_22      582
# 583     15  102         1          Old            27      215_22      583
# 584     16   74         1          Old            28      215_22      584
# 585     17   93         1          Old            29      215_22      585
# 586     18   66         1          Old            30      215_22      586
# 587     19   26         0        Young            31      215_22      587
# 588     20   94         1          Old            32      215_22      588
#
#      AgentIncome  AgentPurchaseThreshold  AgentRentThreshold  ...  \
# 0          10289                 10789.5           3086.9504  ...
# 1          11240                840012.3           3372.2504  ...
# 2          12913               1207852.2           3874.1504  ...
# 3           6489               1198841.7           1946.9504  ...
# 4          14687                288981.9           4406.3504  ...
# 5          14228               1451424.9           4268.6504  ...
# 6          23963               1391388.0           7189.0504  ...
# 7           9213                673560.3           2764.1504  ...
# 8           9412                355167.3           2823.8504  ...
# 9          13974               1065302.1           4192.4504  ...
# 10         23139                 25935.0           6941.8504  ...
# 11         20789                359687.7           6236.8504  ...
# 12         13361               1056700.5           4008.5504  ...
# 13         10367               1065704.7           3110.3504  ...
# 14          8367               1370330.4           2510.3504  ...
# 15         21073               1244471.1           6322.0504  ...
# 16         20674                414887.1           6202.3504  ...
# 17         25100               1466729.1           7530.1504  ...
# 18         15759                492503.7           4727.7800  ...
# 19         17085                814489.8           5125.5800  ...
# 20         16591                495747.0           4977.3800  ...
# 21         29324                  9336.6           8797.4800  ...
# 22         29093                870723.3           8728.1800  ...
# 23         15494               1247958.9           4648.2800  ...
# 24          6260                678118.2           1878.0800  ...
# 25         13516                380211.0           4054.8800  ...
# 26          7351                938598.9           2205.3800  ...
# 27         27416                 63314.7           8225.0800  ...
# 28         27366                743060.1           8210.0800  ...
# 29         12387                788736.0           3716.1800  ...
# ..           ...                     ...                 ...  ...
# 559        13210               1343093.4           3963.1566  ...
# 560        16819                486478.5           5045.8566  ...
# 561        11079               1034931.9           3323.8566  ...
# 562        20015               1384482.6           6004.6566  ...
# 563         9537               1352835.3           2861.2566  ...
# 564        17577               1090814.4           5273.2566  ...
# 565        15666                 50135.4           4699.9566  ...
# 566        11077                683081.1           3323.2566  ...
# 567        14642                635636.1           4392.7566  ...
# 568        26709                360533.0           8012.0000  ...
# 569        26308                136510.0           7892.0000  ...
# 570         7970               1116019.0           2391.0000  ...
# 571        13903               1033959.0           4170.0000  ...
# 572        30079                477413.0           9023.0000  ...
# 573         5517                887979.0           1655.0000  ...
# 574        12217               1020145.0           3665.0000  ...
# 575        29429               1354464.0           8828.0000  ...
# 576        16354               1126625.0           4906.0000  ...
# 577        25635                219503.0           7690.0000  ...
# 578        29272                  2252.0           8781.0000  ...
# 579        27252               1033418.0           8175.0000  ...
# 580         9656                649859.0           2896.0000  ...
# 581         8740                740839.0           2622.0000  ...
# 582         9405                877687.0           2821.0000  ...
# 583        27656               1066787.0           8296.0000  ...
# 584        17093                536491.0           5127.0000  ...
# 585        16175                488146.0           4852.0000  ...
# 586        28583               1084019.0           8574.0000  ...
# 587        25415                810074.0           7624.0000  ...
# 588        26326               1063029.0           7897.0000  ...
#
#      Native_Seniority OwnerShip  OwnershipDesc RentTreshold  \
# 0                  29         1          Owner       3086.7
# 1                  33         1          Owner       3372.0
# 2                  10         1          Owner       3873.9
# 3                  28         1          Owner       1946.7
# 4                  33         1          Owner       4406.1
# 5                  44         1          Owner       4268.4
# 6                  18         0           Rent       7188.9
# 7                  48         1          Owner       2763.9
# 8                  15         1          Owner       2823.6
# 9                  17         1          Owner       4192.2
# 10                 11         0           Rent       6941.7
# 11                 24         0           Rent       6236.7
# 12                 38         1          Owner       4008.3
# 13                 13         1          Owner       3110.1
# 14                 22         1          Owner       2510.1
# 15                 10         0           Rent       6321.9
# 16                 42         0           Rent       6202.2
# 17                 32         0           Rent       7530.0
# 18                 44         1          Owner       4727.7
# 19                 24         1          Owner       5125.5
# 20                 30         1          Owner       4977.3
# 21                 31         0           Rent       8797.2
# 22                 12         0           Rent       8727.9
# 23                 12         1          Owner       4648.2
# 24                 48         1          Owner       1878.0
# 25                 17         1          Owner       4054.8
# 26                 39         1          Owner       2205.3
# 27                 46         0           Rent       8224.8
# 28                 17         0           Rent       8209.8
# 29                 15         1          Owner       3716.1
# ..                ...       ...            ...          ...
# 559                43         1          Owner       3963.0
# 560                49         0           Rent       5045.7
# 561                30         1          Owner       3323.7
# 562                27         0           Rent       6004.5
# 563                19         1          Owner       2861.1
# 564                10         0           Rent       5273.1
# 565                22         1          Owner       4699.8
# 566                22         1          Owner       3323.1
# 567                38         1          Owner       4392.6
# 568                 0         0           Rent       8012.7
# 569                 0         0           Rent       7892.4
# 570                 0         1          Owner       2391.0
# 571                 0         1          Owner       4170.9
# 572                 0         0           Rent       9023.7
# 573                 0         1          Owner       1655.1
# 574                 0         1          Owner       3665.1
# 575                 0         0           Rent       8828.7
# 576                 0         1          Owner       4906.2
# 577                 0         0           Rent       7690.5
# 578                 0         0           Rent       8781.6
# 579                 0         0           Rent       8175.6
# 580                 0         1          Owner       2896.8
# 581                 0         1          Owner       2622.0
# 582                 0         1          Owner       2821.5
# 583                 0         0           Rent       8296.8
# 584                 0         1          Owner       5127.9
# 585                 0         1          Owner       4852.5
# 586                 0         0           Rent       8574.9
# 587                 0         0           Rent       7624.5
# 588                 0         0           Rent       7897.8
#
#     TaxAndMainTreshold iteration  ones  laeving  new comers staying
# 0               3086.7         0     1      NaN         NaN     1.0
# 1               3372.0         0     1      NaN         NaN     1.0
# 2               3873.9         0     1      NaN         NaN     1.0
# 3               1946.7         0     1      NaN         NaN     1.0
# 4               4406.1         0     1      NaN         NaN     1.0
# 5               4268.4         0     1      NaN         NaN     1.0
# 6               7188.9         0     1      1.0         NaN     NaN
# 7               2763.9         0     1      NaN         NaN     1.0
# 8               2823.6         0     1      NaN         NaN     1.0
# 9               4192.2         0     1      NaN         NaN     1.0
# 10              6941.7         0     1      1.0         NaN     NaN
# 11              6236.7         0     1      1.0         NaN     NaN
# 12              4008.3         0     1      NaN         NaN     1.0
# 13              3110.1         0     1      NaN         NaN     1.0
# 14              2510.1         0     1      NaN         NaN     1.0
# 15              6321.9         0     1      1.0         NaN     NaN
# 16              6202.2         0     1      1.0         NaN     NaN
# 17              7530.0         0     1      1.0         NaN     NaN
# 18              4727.7         0     1      NaN         NaN     1.0
# 19              5125.5         0     1      NaN         NaN     1.0
# 20              4977.3         0     1      NaN         NaN     1.0
# 21              8797.2         0     1      NaN         NaN     1.0
# 22              8727.9         0     1      NaN         NaN     1.0
# 23              4648.2         0     1      NaN         NaN     1.0
# 24              1878.0         0     1      NaN         NaN     1.0
# 25              4054.8         0     1      NaN         NaN     1.0
# 26              2205.3         0     1      NaN         NaN     1.0
# 27              8224.8         0     1      NaN         NaN     1.0
# 28              8209.8         0     1      NaN         NaN     1.0
# 29              3716.1         0     1      NaN         NaN     1.0
# ..                 ...       ...   ...      ...         ...     ...
# 559             3963.0         0     1      NaN         NaN     1.0
# 560             5045.7         0     1      NaN         NaN     1.0
# 561             3323.7         0     1      NaN         NaN     1.0
# 562             6004.5         0     1      NaN         NaN     1.0
# 563             2861.1         0     1      NaN         NaN     1.0
# 564             5273.1         0     1      NaN         NaN     1.0
# 565             4699.8         0     1      NaN         NaN     1.0
# 566             3323.1         0     1      NaN         NaN     1.0
# 567             4392.6         0     1      NaN         NaN     1.0
# 568             8012.7         0     1      NaN         1.0     NaN
# 569             7892.4         0     1      NaN         1.0     NaN
# 570             2391.0         0     1      NaN         1.0     NaN
# 571             4170.9         0     1      NaN         1.0     NaN
# 572             9023.7         0     1      NaN         1.0     NaN
# 573             1655.1         0     1      NaN         1.0     NaN
# 574             3665.1         0     1      NaN         1.0     NaN
# 575             8828.7         0     1      NaN         1.0     NaN
# 576             4906.2         0     1      NaN         1.0     NaN
# 577             7690.5         0     1      NaN         1.0     NaN
# 578             8781.6         0     1      NaN         1.0     NaN
# 579             8175.6         0     1      NaN         1.0     NaN
# 580             2896.8         0     1      NaN         1.0     NaN
# 581             2622.0         0     1      NaN         1.0     NaN
# 582             2821.5         0     1      NaN         1.0     NaN
# 583             8296.8         0     1      NaN         1.0     NaN
# 584             5127.9         0     1      NaN         1.0     NaN
# 585             4852.5         0     1      NaN         1.0     NaN
# 586             8574.9         0     1      NaN         1.0     NaN
# 587             7624.5         0     1      NaN         1.0     NaN
# 588             7897.8         0     1      NaN         1.0     NaN
#
# [589 rows x 27 columns]

# %% [markdown]
# ## save the agents file to a new folder the project folder

# %%
ssi.simulation_folder.value
# Out:
# 'cim_0326_1234'

# %%
simulation_path = ssi.sim_folder+ssi.simulation_name.value+"/"
if (ssi.i==0):
  os.mkdir(simulation_path)

save_iteration = 'agents_itr_'+str(ssi.i)+'.xlsx'
excel_path = simulation_path+save_iteration
agent_i_export.to_excel(excel_path)

if (ssi.i==0):
    #save a copy of Agents 0 for statistics
    ssi.agent_0.to_excel(simulation_path + 'agent_0.xlsx')

# %% [markdown]
# <h1>Step 6. calcualting otther sattistics and saving them to excel files</h1>

# %%
#itr_agents_excel_ds.loc[i,'Excel_File']=excel_path
#itr_agents_excel_ds.loc[i,'Bldg Project or Address']=bld_add_or_complex

# %%
gb = agent_i_export.groupby('AgentBldAdd')
agg1_p = gb.agg({'laeving':'count','new comers':'count','staying':'count'})
agg1_p = agg1_p.reset_index()
agg1_p.loc[i,'iteration']=i
# statistics needs to be added on who leaves
# the aggrgation needs to be made on the ssi level, this is incorrect

# %%
agg1_p
# Out:
#    AgentBldAdd  laeving  new comers  staying  iteration
# 0        102_3        0           0       25        0.0
# 1       208_12        0           0       24        NaN
# 2       209_29        0           0       11        NaN
# 3      209_33c        0           0        5        NaN
# 4        209_4        0           0       21        NaN
# 5        209_6        0           0        6        NaN
# 6        209_8        0           0       40        NaN
# 7       210_11        0           0       12        NaN
# 8       210_16        0           0       19        NaN
# 9       210_18        0           0       12        NaN
# 10      210_56        0           0       10        NaN
# 11       210_8        0           0       42        NaN
# 12      211_11        0           0       12        NaN
# 13       211_7        0           0        2        NaN
# 14       211_9        0           0        1        NaN
# 15      212_53        0           0       33        NaN
# 16     215_12a        0           0        7        NaN
# 17     215_12c        0           0       12        NaN
# 18      215_14        0           0        7        NaN
# 19      215_15        0           0       12        NaN
# 20      215_18        0           0       18        NaN
# 21      215_22        6          21       12        NaN
# 22      215_24        0           0       18        NaN
# 23       215_6        0           0       12        NaN
# 24      216_10        0           0       12        NaN
# 25       216_3        0           0       18        NaN
# 26       216_4        0           0       12        NaN
# 27       216_7        0           0       18        NaN
# 28       217_5        0           0       17        NaN
# 29       220_4        0           0       16        NaN
# 30       225_6        0           0       18        NaN
# 31      225_6a        0           0       18        NaN
# 32       225_8        0           0       36        NaN
# 33      ﻿215_2        0           0       24        NaN

# %%
#agg1 = agg1[agg1['AgentBldAdd'] == bld_add_or_complex] # need to fix to take care of complex projects

# %%
agg1_p['New Total Residence'] = agg1_p['new comers'] + agg1_p['staying']
agg1_p['Old Total Residence'] = agg1_p['laeving'] + agg1_p['staying']
agg1_p['Renewd'] = agg1_p['New Total Residence']>agg1_p['Old Total Residence'] 
agg1_p['Type of Project'] = ssi.typeProject #incorrect!!!! need to convert to list
agg1_p['Percent Left'] = agg1_p['laeving'] /agg1_p['Old Total Residence']
agg1_p['Percent New Comers'] = agg1_p['new comers'] /agg1_p['New Total Residence']
agg1 = agg1_p[agg1_p['Renewd']==True]
agg1.reset_index(inplace=True)

# %%
agg1
# Out:
#    index AgentBldAdd  laeving  new comers  staying  iteration  \
# 0     21      215_22        6          21       12        NaN
#
#    New Total Residence  Old Total Residence  Renewd Type of Project  \
# 0                   33                   18    True       תמ״א 38/1
#
#    Percent Left  Percent New Comers
# 0      0.333333            0.636364

# %%
temp = (agg1[['laeving','new comers','staying','New Total Residence','Old Total Residence']].sum())

# %%
temp
# Out:
# laeving                 6
# new comers             21
# staying                12
# New Total Residence    33
# Old Total Residence    18
# dtype: int64

# %%
 newsum = pd.DataFrame(temp).transpose()

# %%
newsum['itr'] = i
newsum['Percent Left'] = newsum['laeving'] /newsum['Old Total Residence']
newsum['Percent New Comers'] = newsum['new comers'] /newsum['New Total Residence']

# %%
if (i==0):
    agg2 = newsum
else:
    agg2.loc[i] = newsum.loc[0]    #agg2.loc[i,['itr']]=i
    #agg2.loc[i,'itr'] =i
    #agg2.loc[i,'Percent Left']] = newsum['laeving'] /newsum['Old Total Residence']
    #newsum['Percent New Comers'] = newsum['new comers'] /newsum['New Total Residence']

# %%
# save_iteration = 'bldg_itr_'+str(i)+'.xlsx'

# excel_path = simulation_path+save_iteration
# agg1.to_excel(excel_path)
# itr_bldg_excel_ds.loc[i,'Excel_File']=excel_path
# itr_bldg_excel_ds.loc[i,'BldgOrProjectName']=bld_add_or_complex

# save_iteration = 'accumulated_'+save_iteration
# accumulated_excel_path=simulation_path+save_iteration
# agg2.to_excel(accumulated_excel_path)


# if (i>0):
#   print(i)
#   itr_bldg_excel_ds.loc[i,'Excel_File']=accumulated_excel_path
#   itr_bldg_excel_ds.loc[i,'BldgOrProjectName']=bld_add_or_complex
# else:
#   itr_accumulated_bldg_excel_ds = itr_bldg_excel_ds
# Out:
# 17

# %% [markdown]
# ## Need to Add Geographic Representation and saving
# ## Need to Add Plotly

# %%
itr_agent_path = simulation_path+'agents_iteration_excels.xlsx'
itr_bldg_path = simulation_path+'bldg_iteration_excels.xlsx'
#itr_geopacakge_path = simulation_path+'iteration_geopackage.xlsx'
accum_path = simulation_path+'itr_accumnulated_bldg.xlsx'
#itr_bldg_excel_ds.to_excel(itr_bldg_path)
#itr_agents_excel_ds.to_excel(itr_agent_path)
#itr_geokpackage_ds.to_excel(itr_geopacakge_path)
itr_accumulated_bldg_excel_ds.to_excel(accum_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-08e9686f7119> in <module>
#       6 #itr_agents_excel_ds.to_excel(itr_agent_path)
#       7 #itr_geokpackage_ds.to_excel(itr_geopacakge_path)
# ----> 8 itr_accumulated_bldg_excel_ds.to_excel(accum_path)
#
# NameError: name 'itr_accumulated_bldg_excel_ds' is not defined

# %% [markdown]
# <h1 >TODO 1. !!! Need to create a flat file with a description of all the projects for each building</h1>

# %%
def generateAgensts(thisDS):
    #this function recievs data from new building dataset and returns new renters or owners
    nUnits = len(thisDS['appUnits'])

    rand_income_rent = np.random.randint(0, high=5000, size=nUnits, dtype='l') #monthly income
    rand_inc_sr_rent =  pd.Series(rand_income_rent) #turning this into series

    rand_income_own = np.random.randint(3000, high=15000, size=nUnits, dtype='l') #monthly income
    rand_inc_sr_own =  pd.Series(rand_income_own) #into series
    
    rand_wealth = np.random.randint(0, high=5000000, size=nUnits, dtype='l') #wealth
    age = np.random.randint(25, high=110, size=nUnits, dtype='l') #wealth
    ownership = np.random.randint(0, high=2, size=nUnits, dtype='l') #0 rent 1 owns
    
    ds = pd.DataFrame()
    
    ds['OwnerShip'] = pd.Series(ownership)
    ds['AgentAppUnit'] = thisDS['appUnits'] #what unit does the agent live in
    ds['AgentBldAdd'] = thisDS['bldAdd'] # in what bld address does the Agent live in

 
    ds['AgentWealth'] = pd.Series(rand_wealth)
    
    ds['AgentPurchaseThreshold'] = (ds['AgentWealth'] * 0.3).astype(int) # 30% of wealth, Agent can buy a house without Mortgage
    ds['Age'] = pd.Series(age)
    
    ds['AgeGroup'] = ds['Age'].apply(lambda x: 0 if x < 65 else 1)
    ds['Native_Seniority'] = 0
    ds['Native_Group'] = ds['Native_Seniority'].apply(lambda x: 0 if x < 10 else 1) # 0 Native, 1 NewComer
    
    # for renters take the rent price
    ds.loc[ds['OwnerShip']==0,'AgentIncome'] = (thisDS[ds['OwnerShip']==0]['rentPerMonth'])/0.3 + rand_inc_sr_rent[ds['OwnerShip']==0]
    ds.loc[ds['OwnerShip']==1,'AgentIncome'] = (thisDS[ds['OwnerShip']==1]['newMaintenace&Tax'])/0.3 + rand_inc_sr_own[ds['OwnerShip']==1]
    ds['AgentIncome'] = ds['AgentIncome'].astype(int)
    ds['AgentRentThreshold'] = (ds['AgentIncome'] * 0.3).astype(int) # 30% of income
    
    #Age Formating
    ds['AgeGroupDesc'] = ds['Age'].apply(lambda x: 'Young' if x < 65 else 'Old')
    #Native Formating
    ds['NativeDesc'] = ds['Native_Group'].apply(lambda x: 'Native' if x == 1 else 'New Comers')
    #Ownership Formating
    ds['OwnershipDesc'] = ds['OwnerShip'].apply(lambda x: 'Owner' if x == 1 else 'Rent')
    
    LowInc = int(ssi.rules['Income']['Low']['0'])
    MediumInc = int(ssi.rules['Income']['Medium']['1'])
    HighInc = int(ssi.rules['Income']['High']['2'])
    
    ds['IncomeNum'] = ds['AgentIncome'].apply(lambda x: "0" if x < LowInc else "1" if x < MediumInc else "2")
    ds['IncomeDesc'] = ds['AgentIncome'].apply(lambda x: 'Low Income' if x < LowInc else 'Medium Income' if x < MediumInc else "High Income")
    ds = updateAgentsThresholdData(ds,'new comers')

    return ds

# %%
def updateAgentsThresholdData(ds,status):
    #This function recieves a Agent Dataset
    #The function returns the agents ability to live in a certain building as column data
    ds['TaxAndMainTreshold'] = ds['AgentIncome']*0.3
    ds['RentTreshold'] = ds['AgentIncome']*0.3
    ds['BuyTreshold'] = ds['AgentWealth']*0.3
    ds['Agent_status'] = status #staying, leaving,newComers buying always starts with staying
    return ds

# %% [markdown]
# # Useful Pivot Operations (Reference)

# %%
ssi.agent_ref.head(4)
# Out:
#    Unnamed: 0  AgentAppUnit AgentBldAdd  AgentIncome  AgentWealth  \
# 0           0             0      215_22        13842       697698
# 1           1             1      215_22         7319       431148
# 2           2             2      215_22        14488      2666059
# 3           3             3      215_22         7655      4475813
#
#    AgentPurchaseThreshold  AgentRentThreshold  Age  OwnerShip  AgeGroup  \
# 0                209309.4           4152.8504   98          1         1
# 1                129344.4           2195.9504   53          1         0
# 2                799817.7           4346.6504   73          1         1
# 3               1342743.9           2296.7504  108          1         1
#
#    Native_Seniority  Native_Group  AgentID AgeGroupDesc NativeDesc  \
# 0                37             1        0          Old     Native
# 1                45             1        1        Young     Native
# 2                30             1        2          Old     Native
# 3                39             1        3          Old     Native
#
#   OwnershipDesc  IncomeNum     IncomeDesc
# 0         Owner          1  Medium Income
# 1         Owner          0     Low Income
# 2         Owner          1  Medium Income
# 3         Owner          0     Low Income

# %%
agg_by_bldg = ssi.agent_ref.pivot_table(index=['AgentBldAdd'],columns='IncomeDesc',values='AgentIncome',aggfunc='count')
agg_by_bldg.head()
# Out:
# IncomeDesc   High Income  Low Income  Medium Income
# AgentBldAdd
# 209_6                3.0         NaN            3.0
# 210_16               NaN         4.0           15.0
# 210_18               3.0         1.0            8.0
# 211_11               9.0         1.0            2.0
# 211_7                1.0         NaN            1.0

# %%
agg_by_bldg.reset_index(inplace=True)

# %%
agg_by_bldg.columns
# Out:
# Index(['AgentBldAdd', 'High Income', 'Low Income', 'Medium Income'], dtype='object', name='IncomeDesc')

# %%
agg_by_bldg.columns.rename("row",inplace=True)

# %%
agg_by_bldg.head()
# Out:
# row AgentBldAdd  High Income  Low Income  Medium Income
# 0         209_6          3.0         NaN            3.0
# 1        210_16          NaN         4.0           15.0
# 2        210_18          3.0         1.0            8.0
# 3        211_11          9.0         1.0            2.0
# 4         211_7          1.0         NaN            1.0

# %%
agg_by_bldg.set_index('AgentBldAdd', inplace=True)

# %%
agg_by_bldg.head()
# Out:
# row          High Income  Low Income  Medium Income
# AgentBldAdd
# 209_6                3.0         NaN            3.0
# 210_16               NaN         4.0           15.0
# 210_18               3.0         1.0            8.0
# 211_11               9.0         1.0            2.0
# 211_7                1.0         NaN            1.0

# %%
del agg_by_bldg.index.name

# %%
agg_by_bldg
# Out:
# row     High Income  Low Income  Medium Income
# 209_6           3.0         NaN            3.0
# 210_16          NaN         4.0           15.0
# 210_18          3.0         1.0            8.0
# 211_11          9.0         1.0            2.0
# 211_7           1.0         NaN            1.0
# 211_9           NaN         NaN            1.0
# 215_22          5.0         4.0            9.0
# 216_10          4.0         2.0            6.0
# 216_4           4.0         6.0            2.0

# %%
agg_by_bldg1 = ssi.agent_ref.pivot(index='AgentID',columns='IncomeDesc',values='AgentIncome')

# %%
agg_by_bldg1.head()
# Out:
# IncomeDesc  High Income  Low Income  Medium Income
# AgentID
# 0                   NaN         NaN        13842.0
# 1                   NaN      7319.0            NaN
# 2                   NaN         NaN        14488.0
# 3                   NaN      7655.0            NaN
# 4                   NaN      5067.0            NaN

# %%
del agg_by_bldg1.index.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-460-bc41cb070356> in <module>
# ----> 1 del agg_by_bldg1.index.name
#
# AttributeError: name

# %%
agg_by_bldg1.head()
# Out:
# IncomeDesc  High Income  Low Income  Medium Income
# 0                   NaN         NaN        13842.0
# 1                   NaN      7319.0            NaN
# 2                   NaN         NaN        14488.0
# 3                   NaN      7655.0            NaN
# 4                   NaN      5067.0            NaN
